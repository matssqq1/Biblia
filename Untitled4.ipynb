# %% [markdown]
# <a href="https://colab.research.google.com/github/matssqq1/Biblia/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df1=pd.read_csv("/content/part_01.csv")
df2=pd.read_csv("/content/part_02.csv")
df3=pd.read_csv("/content/part_03.csv")
df4=pd.read_csv("/content/part_04.csv")
df5=pd.read_csv("/content/part_05.csv")
df6=pd.read_csv("/content/part_06.csv")
df7=pd.read_csv("/content/part_07.csv")
df8=pd.read_csv("/content/part_08.csv")
df9=pd.read_csv("/content/part_09.csv")
df10=pd.read_csv("/content/part_10.csv")
df11=pd.read_csv("/content/part_11.csv")
df12=pd.read_csv("/content/part_12.csv")

df1.merge(df2, left_on='ID', right_on='ID').merge(df3, left_on='ID', right_on='ID').merge(df4, left_on='ID', right_on='ID').merge(df5, left_on='ID', right_on='ID').merge(df6, left_on='ID', right_on='ID')
df1 = pd.concat([df7, df8, df9, df10,df11,df12], ignore_index=True)
cd = df1
cd.sort_values(by="ID")
cd.drop_duplicates
cd.head(10)
#print(f"rows: {cd.shape[0]}, columns: {cd.shape[1]}")
#print(cd.duplicated().any())
#cd.info(verbose=True)
cd.APP_COMP_TYPE = cd.APP_COMP_TYPE.str.lower()
spisok = [x for x in list(cd.APP_COMP_TYPE.unique()) if x == x]
spisok.sort()
spisok
# Out:
# ['inter', 'ip', 'private', 'state']

# %%
cd.APP_COMP_TYPE.unique()
# Out:
# array([nan, 'private', 'state', 'inter', 'ip'], dtype=object)

# %%
cd.select_dtypes(include='object')
# Out:
#         CLNT_JOB_POSITION CLNT_JOB_POSITION_TYPE CLNT_TRUST_RELATION  \
# 0                     NaN                    NaN                 NaN
# 1                     NaN                    NaN                 NaN
# 2             AHD MANAGER                    NaN                 NaN
# 3                DIRECTOR                    NaN                 NaN
# 4                  SELLER                    NaN                 NaN
# ...                   ...                    ...                 ...
# 1065565               NaN                    NaN                 NaN
# 1065566               NaN                    NaN                 NaN
# 1065567               NaN                    NaN                 NaN
# 1065568               NaN                    NaN                 NaN
# 1065569               NaN                    NaN                 NaN
#
#              PACK APP_CAR APP_COMP_TYPE APP_DRIVING_LICENSE APP_EDUCATION  \
# 0        O0FATHER     NaN           NaN                 NaN           NaN
# 1        FATHER02     NaN           NaN                 NaN           NaN
# 2        FATHER02     NaN           NaN                 NaN           NaN
# 3        K0FATHER     NaN           NaN                 NaN           NaN
# 4        FATHER05     NaN           NaN                 NaN           NaN
# ...           ...     ...           ...                 ...           ...
# 1065565       NaN     NaN           NaN                 NaN           NaN
# 1065566       NaN     NaN           NaN                 NaN           NaN
# 1065567       NaN     NaN           NaN                 NaN           NaN
# 1065568       NaN     NaN           NaN                 NaN           NaN
# 1065569       NaN     NaN           NaN                 NaN           NaN
#
#         APP_EMP_TYPE APP_KIND_OF_PROP_HABITATION APP_MARITAL_STATUS  \
# 0                NaN                         NaN                NaN
# 1                NaN                         NaN                NaN
# 2                NaN                         NaN                NaN
# 3                NaN                         NaN                NaN
# 4                NaN                         NaN                NaN
# ...              ...                         ...                ...
# 1065565          NaN                         NaN                NaN
# 1065566          NaN                         NaN                NaN
# 1065567          NaN                         NaN                NaN
# 1065568          NaN                         NaN                NaN
# 1065569          NaN                         NaN                NaN
#
#         APP_POSITION_TYPE APP_TRAVEL_PASS
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 1065565               NaN             NaN
# 1065566               NaN             NaN
# 1065567               NaN             NaN
# 1065568               NaN             NaN
# 1065569               NaN             NaN
#
# [1065570 rows x 13 columns]

# %%
cd.	CLNT_JOB_POSITION.unique()
# Out:
# array([nan, 'AHD MANAGER', 'DIRECTOR', ..., 'DEPUTY DIRECTOR',
#        'ASSISTANT TO THE CHAIRMAN OF THE MANAGEMENT BOARD',
#        'ST ADMINISTRATOR'], dtype=object)

# %%
cd = cd.replace('RELATIVE', '', regex=True)

# %%
cd.APP_MARITAL_STATUS.unique()
# Out:
# array([nan, 'M', 'D', 'V', 'T', 'm', 'N', 'v', 'd', 't', 'W', 'C', ' ',
#        'w'], dtype=object)

# %%
cd = cd.replace('продавец', 'SELLER', regex=True)

# %%
cd = cd.replace('ПОМОЩНИК ПРЕДСЕДАТЕЛЯ ПРАВЛЕНИЯ', 'ASSISTANT TO THE CHAIRMAN OF THE MANAGEMENT BOARD', regex=True)

# %%
cd.APP_COMP_TYPE.unique()

# %%
cd.APP_COMP_TYPE.unique()

# %%
cd.APP_COMP_TYPE.unique()
